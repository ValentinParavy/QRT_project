# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from sklearn import model_selection
from sklearn.metrics import accuracy_score
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.preprocessing import MinMaxScaler
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt
import os
import sys
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/My Drive/QRT_FOOT_DATA_CHALLENGE')

# %%
from Utilities.data_process import scores_to_target
from Utilities.get_data import get_train
from Utilities.bench_validation import test_bench
#from Clustering.clustering import kmeans_clustering

# %%
os.chdir('/content/drive/My Drive/QRT_FOOT_DATA_CHALLENGE/Utilities/Data')
train_data, train_scores = get_train()

# %%
def fill_with_BayesianBridge(train_data, train_scores, normalize = True, max_iter = 100, tol = 0.01):
  train_data_init = train_data.copy()
  if(normalize):
    scaler = MinMaxScaler()
    train_data_processed = scaler.fit_transform(train_data)
  imputer = IterativeImputer(max_iter=max_iter, add_indicator=True, tol=tol, verbose=1)
  train_data_processed = imputer.fit_transform(train_data_processed)
  if(normalize):
    train_data_processed = scaler.inverse_transform(train_data_processed)
  train_target = scores_to_target(train_scores)
  train_data_init.values = train_data_processed
  return train_data_init, train_target

# %%
train_data, train_scores = get_train()
train_data, train_target = fill_with_BayesianBridge(train_data, train_scores)
# Out:
# [IterativeImputer] Completing matrix with shape (12303, 280)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-fe0ac0d8a581> in <cell line: 2>()
#       1 train_data, train_scores = get_train()
# ----> 2 train_data, train_target = fill_with_BayesianBridge(train_data, train_scores)
#
# <ipython-input-9-2adfe1dd4c59> in fill_with_BayesianBridge(train_data, train_scores, normalize, max_iter, tol)
#       5     train_data_processed = scaler.fit_transform(train_data)
#       6   imputer = IterativeImputer(max_iter=max_iter, add_indicator=True, tol=tol, verbose=1)
# ----> 7   train_data_processed = imputer.fit_transform(train_data_processed)
#       8   if(normalize):
#       9     train_data_processed = scaler.inverse_transform(train_data_processed)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     314     @wraps(f)
#     315     def wrapped(self, X, *args, **kwargs):
# --> 316         data_to_wrap = f(self, X, *args, **kwargs)
#     317         if isinstance(data_to_wrap, tuple):
#     318             # only wrap the first output for cross decomposition
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_iterative.py in fit_transform(self, X, y, **params)
#     787                     n_features, feat_idx, abs_corr_mat
#     788                 )
# --> 789                 Xt, estimator = self._impute_one_feature(
#     790                     Xt,
#     791                     mask_missing_values,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/impute/_iterative.py in _impute_one_feature(self, X_filled, mask_missing_values, feat_idx, neighbor_feat_idx, estimator, fit_mode, params)
#     416                 axis=0,
#     417             )
# --> 418             estimator.fit(X_train, y_train, **params)
#     419
#     420         # if no missing values, don't predict
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in wrapper(estimator, *args, **kwargs)
#    1471                 )
#    1472             ):
# -> 1473                 return fit_method(estimator, *args, **kwargs)
#    1474
#    1475         return wrapper
#
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_bayes.py in fit(self, X, y, sample_weight)
#     285
#     286         XT_y = np.dot(X.T, y)
# --> 287         U, S, Vh = linalg.svd(X, full_matrices=False)
#     288         eigen_vals_ = S**2
#     289
#
# /usr/local/lib/python3.10/dist-packages/scipy/linalg/_decomp_svd.py in svd(a, full_matrices, compute_uv, overwrite_a, check_finite, lapack_driver)
#     139
#     140     # perform decomposition
# --> 141     u, s, v, info = gesXd(a1, compute_uv=compute_uv, lwork=lwork,
#     142                           full_matrices=full_matrices, overwrite_a=overwrite_a)
#     143
#
# KeyboardInterrupt:

# %%
scores_cross_val = test_bench(train_data, train_target)
